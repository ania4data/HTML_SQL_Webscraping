# %%
import numpy as np
import pandas as pd
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0].head(30)
# Out:
#                                             Bank Name                City  ST  \
# 0                 Washington Federal Bank for Savings             Chicago  IL
# 1     The Farmers and Merchants State Bank of Argonia             Argonia  KS
# 2                                 Fayette County Bank          Saint Elmo  IL
# 3   Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 4                                      First NBC Bank         New Orleans  LA
# 5                                       Proficio Bank  Cottonwood Heights  UT
# 6                       Seaway Bank and Trust Company             Chicago  IL
# 7                              Harvest Community Bank          Pennsville  NJ
# 8                                         Allied Bank            Mulberry  AR
# 9                        The Woodbury Banking Company            Woodbury  GA
# 10                             First CornerStone Bank     King of Prussia  PA
# ...

# %%
df[0]
# Out:
#                                              Bank Name                City  \
# 0                  Washington Federal Bank for Savings             Chicago
# 1      The Farmers and Merchants State Bank of Argonia             Argonia
# 2                                  Fayette County Bank          Saint Elmo
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 4                                       First NBC Bank         New Orleans
# 5                                        Proficio Bank  Cottonwood Heights
# 6                        Seaway Bank and Trust Company             Chicago
# 7                               Harvest Community Bank          Pennsville
# 8                                          Allied Bank            Mulberry
# 9                         The Woodbury Banking Company            Woodbury
# 10                              First CornerStone Bank     King of Prussia
# ...

# %%
import urllib.request as urllib
response = urllib.urlopen('http://www.fdic.gov/bank/individual/failed/banklist.html')
html = response.read()

# %%
html
# Out:
# b'<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->\n\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js">\n\n    <meta name="application-name" content="Python.org">\n    <meta name="msapplication-tooltip" content="The official home of the Python Programming Language">\n    <meta name="apple-mobile-web-app-title" content="Python.org">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="
# ...

# %%
#!/usr/bin/python2.4
#
# Small script to show PostgreSQL and Pyscopg together
#

import psycopg2

try:
    conn = psycopg2.connect("dbname='dvdrental' user='postgres' host='localhost' password='test'")
except:
    print ("I am unable to connect to the database")

# %%
cur = conn.cursor()
try:
    cur.execute("""SELECT * from actor""")
except:
    print( "I can't SELECT from actor")

rows = cur.fetchall()
print ("\nRows: \n")
for row in rows:
    print ("   ", row)
# Out:
# Rows:
#
#     (1, 'Penelope', 'Guiness', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (2, 'Nick', 'Wahlberg', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (3, 'Ed', 'Chase', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (4, 'Jennifer', 'Davis', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (5, 'Johnny', 'Lollobrigida', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (6, 'Bette', 'Nicholson', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (7, 'Grace', 'Mostel', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (8, 'Matthew', 'Johansson', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (9, 'Joe', 'Swank', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (10, 'Christian', 'Gable', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (11, 'Zero', 'Cage', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
#     (12, 'Karl', 'Berry', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))
# ...

# %%
#!/usr/bin/python

hostname = 'localhost'
username = 'postgres'
password = 'test'
database = 'dvdrental'

# Simple routine to run a query on a database and print the results:
def doQuery(conn) :
    cur = conn.cursor()

    cur.execute( "SELECT first_name, last_name FROM actor" )

    for row in cur.fetchall() :
        print(row)


print ("Using psycopg2…")
import psycopg2
myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
doQuery(myConnection)
myConnection.close()
# Out:
# Using psycopg2…
# ('Penelope', 'Guiness')
# ('Nick', 'Wahlberg')
# ('Ed', 'Chase')
# ('Jennifer', 'Davis')
# ('Johnny', 'Lollobrigida')
# ('Bette', 'Nicholson')
# ('Grace', 'Mostel')
# ('Matthew', 'Johansson')
# ('Joe', 'Swank')
# ('Christian', 'Gable')
# ('Zero', 'Cage')
# ('Karl', 'Berry')
# ('Uma', 'Wood')
# ('Vivien', 'Bergen')
# ('Cuba', 'Olivier')
# ('Fred', 'Costner')
# ('Helen', 'Voight')
# ('Dan', 'Torn')
# ('Bob', 'Fawcett')
# ('Lucille', 'Tracy')
# ('Kirsten', 'Paltrow')
# ('Elvis', 'Marx')
# ('Sandra', 'Kilmer')
# ('Cameron', 'Streep')
# ('Kevin', 'Bloom')
# ('Rip', 'Crawford')
# ('Julia', 'Mcqueen')
# ('Woody', 'Hoffman')
# ('Alec', 'Wayne')
# ('Sandra', 'Peck')
# ('Sissy', 'Sobieski')
# ('Tim', 'Hackman')
# ('Milla', 'Peck')
# ('Audrey', 'Olivier')
# ('Judy', 'Dean')
# ('Burt', 'Dukakis')
# ('Val', 'Bolger')
# ('Tom', 'Mckellen')
# ('Goldie', 'Brody')
# ('Johnny', 'Cage')
# ('Jodie', 'Degeneres')
# ('Tom', 'Miranda')
# ('Kirk', 'Jovovich')
# ('Nick', 'Stallone')
# ...

# %%
#!/usr/bin/python
hostname = 'localhost'
username = 'postgres'
password = 'test'
database = 'dvdrental'

from sqlalchemy import create_engine


myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )

df = pd.read_sql_query('select * from actor',con=myConnection)
dg = pd.read_sql_query('select * from film',con=myConnection)
myConnection.close()

# %%
df.head()
# Out:
#    actor_id first_name     last_name             last_update
# 0         1   Penelope       Guiness 2013-05-26 14:47:57.620
# 1         2       Nick      Wahlberg 2013-05-26 14:47:57.620
# 2         3         Ed         Chase 2013-05-26 14:47:57.620
# 3         4   Jennifer         Davis 2013-05-26 14:47:57.620
# 4         5     Johnny  Lollobrigida 2013-05-26 14:47:57.620

# %%
dg.head()
# Out:
#    film_id              title  \
# 0      133    Chamber Italian
# 1      384   Grosse Wonderful
# 2        8    Airport Pollock
# 3       98  Bright Encounters
# 4        1   Academy Dinosaur
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
# 1  A Epic Drama of a Cat And a Explorer who must ...          2006
# 2  A Epic Tale of a Moose And a Girl who must Con...          2006
# 3  A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4  A Epic Drama of a Feminist And a Mad Scientist...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                7         4.99     117             14.99  NC-17
# 1            1                5         4.99      49             19.99      R
# 2            1                6         4.99      54             15.99      R
# ...

# %%
dg['fulltext'][0]
# Out:
# "'chamber':1 'fate':4 'husband':11 'italian':2 'monkey':16 'moos':8 'must':13 'nigeria':18 'overcom':14 'reflect':5"

# %%
dh=dg['fulltext'].apply(lambda x:x.split(' '))

# %%
list
for item in np.arange(0,202):
        print(item,dh[item][0])
# Out:
# 0 'chamber':1
# 1 'australia':18
# 2 'airport':1
# 3 'boat':20
# 4 'academi':1
# 5 'ace':1
# 6 'adapt':1
# 7 'affair':1
# 8 'african':1
# 9 'agent':1
# 10 'airplan':1
# 11 'administr':9
# 12 'action':5
# 13 'alamo':1
# 14 'alaska':1
# 15 'compos':8
# 16 'action':5
# 17 'administr':13
# 18 'alien':1
# 19 'alley':1
# 20 'abandon':22
# 21 'agent':17
# 22 'amadeus':1
# 23 'ameli':1
# 24 'administr':17
# 25 'amistad':1
# 26 'anaconda':1
# 27 'analyz':1
# 28 'angel':1
# 29 'abandon':20
# 30 'administr':9,18
# 31 'abandon':19
# 32 'administr':17
# 33 'abandon':20
# 34 'apach':1
# 35 'abandon':19
# 36 'abandon':22
# 37 'arabia':1
# 38 'action':5
# 39 'abandon':20
# 40 'arizona':1
# 41 'ark':1
# 42 'abandon':21
# 43 'administr':9
# 44 'arsenic':1
# 45 'artist':1
# 46 'boat':8
# 47 'atlanti':1
# 48 'abandon':23
# 49 'ancient':18
# 50 'autumn':1
# 51 'abandon':21
# 52 'backlash':1
# 53 'badman':1
# 54 'bake':1
# 55 'boy':18
# 56 'balloon':1
# 57 'ballroom':1
# 58 'abandon':20
# 59 'awe':5
# ...

# %%
#!/usr/bin/python
hostname = 'localhost'
username = 'postgres'
password = 'test'
database = 'postgres'
import psycopg2
from sqlalchemy import create_engine


myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
cur=myConnection.cursor()
cur2=myConnection.cursor()
cur.execute("CREATE TABLE IF NOT EXISTS employee (name TEXT, ID INTEGER, salary REAL)")
myConnection.commit()
cur2.execute("INSERT INTO employee VALUES('%s','%s','%s')" % ('Sally',1,10000))
myConnection.commit()
myConnection.close()

# %%
#!/usr/bin/python
import sqlalchemy
import pyodbc
hostname = 'localhost'
username = 'postgres'
password = 'test'
database = 'postgres'
import psycopg2
from sqlalchemy import create_engine


myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
cur=myConnection.cursor()
cur.execute("INSERT INTO store VALUES('%s','%s','%s')" % ('Book',10,200))    #delect: delete from.   & view: select from (co  commit)
#df.to_sql('Test_actor',myConnection)
myConnection.commit()
myConnection.close()

# %%
df.head()
# Out:
#    actor_id first_name     last_name             last_update
# 0         1   Penelope       Guiness 2013-05-26 14:47:57.620
# 1         2       Nick      Wahlberg 2013-05-26 14:47:57.620
# 2         3         Ed         Chase 2013-05-26 14:47:57.620
# 3         4   Jennifer         Davis 2013-05-26 14:47:57.620
# 4         5     Johnny  Lollobrigida 2013-05-26 14:47:57.620

# %%
#!/usr/bin/python
hostname = 'localhost'
username = 'postgres'
password = 'test'
database = 'postgres'
import psycopg2
from sqlalchemy import create_engine


myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
engine = create_engine('postgresql://postgres:test@localhost:5432/postgres')    # 'postgresql://username:password@localhost:5432/mydatabase'
engine = create_engine('postgresql+psycopg2://postgres:test@localhost:5432/postgres')
df.to_sql('psycopg2',engine)
myConnection.commit()
myConnection.close()

# %%
#!/usr/bin/python
hostname = 'localhost'
username = 'postgres'
password = 'test'
database = 'postgres'
import psycopg2
from sqlalchemy import create_engine


myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
#engine = create_engine('postgresql://postgres:test@localhost:5432/postgres')    # 'postgresql://username:password@localhost:5432/mydatabase'
engine = create_engine('postgresql+psycopg2://postgres:test@localhost:5432/postgres')
df.to_sql('psycopg3',engine)
myConnection.commit()
myConnection.close()

# %%
hostname = 'localhost'
username = 'postgres'
password = 'test'
database = 'postgres'
import psycopg2
from sqlalchemy import create_engine


myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
#engine = create_engine('postgresql://postgres:test@localhost:5432/postgres')    # 'postgresql://username:password@localhost:5432/mydatabase'
engine = create_engine('postgresql+psycopg2://postgres:test@localhost:5432/postgres')
df.to_sql('psycopg3',engine)
myConnection.commit()
myConnection.close()

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
# %matplotlib inline

#start = datetime.datetime(2006, 1, 1)
#end = datetime.datetime(2016, 1, 1)

#BAC = wb.DataReader('BAC', 'morningstar', start, end).reset_index().set_index('Date').drop(['Symbol'],axis=1)
import pandas_datareader as pdr
pdr.get_data_fred('GS10')

import pandas_datareader.data as web

start = datetime.datetime(2006, 1, 1)
end = datetime.datetime(2016, 1, 1)

BAC = web.DataReader('BAC', 'morningstar', start, end).reset_index().set_index('Date').drop(['Symbol'],axis=1)

BAC.head()
# Out:
#             Close   High    Low   Open    Volume
# Date
# 2006-01-02  46.15  46.36  45.91  46.02         0
# 2006-01-03  47.08  47.18  46.15  46.92  16197900
# 2006-01-04  46.58  47.24  46.45  47.00  17427400
# 2006-01-05  46.64  46.83  46.32  46.58  14668900
# 2006-01-06  46.57  46.91  46.35  46.80  11965700

# %%
hostname = 'localhost'
username = 'postgres'
password = 'test'
database = 'postgres'
import psycopg2
from sqlalchemy import create_engine


myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
engine = create_engine('postgresql://postgres:test@localhost:5432/postgres')    # 'postgresql://username:password@localhost:5432/mydatabase'
#engine = create_engine('postgresql+psycopg2://postgres:test@localhost:5432/postgres')
BAC.to_sql('bank',engine)
myConnection.commit()
myConnection.close()

# %%
import urllib.request as urllib
from bs4 import BeautifulSoup
#response = urllib.urlopen('http://www.fdic.gov/bank/individual/failed/banklist.html')
#html2 = response.read()

# %%
response = urllib.urlopen('http://www.pythonhow.com/example.html')
html2 = response.read()

# %%
html2
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n<style>\ndiv.cities {\n    background-color:black;\n    color:white;\n    margin:20px;\n    padding:20px;\n} \n</style>\n</head>\n<body>\n<h1 align="center"> Here are three big cities </h1>\n<div class="cities">\n<h2>London</h2>\n<p>London is the capital of England and it\'s been a British settlement since 2000 years ago. </p>\n</div>\n<div class="cities">\n<h2>Paris</h2>\n<p>Paris is the capital city of France. It was declared capital since 508.</p>\n</div>\n<div class="cities">\n<h2>Tokyo</h2>\n<p>Tokyo is the capital of Japan and one of the most populated cities in the world.</p>\n</div>\n</body>\n</html>'

# %%
soup=BeautifulSoup(html2,"html.parser")

# %%
print(soup.prettify())   #for demonstration like source file
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <style>
#    div.cities {
#     background-color:black;
#     color:white;
#     margin:20px;
#     padding:20px;
# }
#   </style>
#  </head>
#  <body>
#   <h1 align="center">
#    Here are three big cities
#   </h1>
#   <div class="cities">
#    <h2>
#     London
#    </h2>
#    <p>
#     London is the capital of England and it's been a British settlement since 2000 years ago.
#    </p>
#   </div>
#   <div class="cities">
#    <h2>
#     Paris
#    </h2>
#    <p>
#     Paris is the capital city of France. It was declared capital since 508.
#    </p>
#   </div>
#   <div class="cities">
#    <h2>
#     Tokyo
#    </h2>
#    <p>
#     Tokyo is the capital of Japan and one of the most populated cities in the world.
#    </p>
#   </div>
#  </body>
# </html>

# %%
soup.find_all('div',{'class':'cities'})
# Out:
# [<div class="cities">
#  <h2>London</h2>
#  <p>London is the capital of England and it's been a British settlement since 2000 years ago. </p>
#  </div>, <div class="cities">
#  <h2>Paris</h2>
#  <p>Paris is the capital city of France. It was declared capital since 508.</p>
#  </div>, <div class="cities">
#  <h2>Tokyo</h2>
#  <p>Tokyo is the capital of Japan and one of the most populated cities in the world.</p>
#  </div>]

# %%
soup.find_all('div',{'class':'cities'})[0]
# Out:
# <div class="cities">
# <h2>London</h2>
# <p>London is the capital of England and it's been a British settlement since 2000 years ago. </p>
# </div>

# %%
soup.find_all('div',{'class':'cities'})[0].find_all('h2')[0]
# Out:
# <h2>London</h2>

# %%
soup.find_all('div',{'class':'cities'})[0].find_all('h2')[0].text
# Out:
# 'London'

# %%
soup.find_all('div',{'class':'cities'})[1].find_all('h2')[0].text
# Out:
# 'Paris'

# %%
soup.find_all('div',{'class':'cities'})[2].find_all('h2')[0].text
# Out:
# 'Tokyo'

# %%
all=soup.find_all('div',{'class':'cities'})

# %%
for item in all:
    print(item.find_all('h2')[0].text)
# Out:
# London
# Paris
# Tokyo

# %%
for item in all:
    print(item.find_all('p')[0].text)
# Out:
# London is the capital of England and it's been a British settlement since 2000 years ago.
# Paris is the capital city of France. It was declared capital since 508.
# Tokyo is the capital of Japan and one of the most populated cities in the world.

# %%
import urllib.request as urllib
from bs4 import BeautifulSoup

# %%
response = urllib.urlopen('https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/')
html3 = response.read()
#html3

# %%
soup=BeautifulSoup(html3,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" style="margin: 0px;overflow:hidden"><script async="" src="./LCWYROCKSPRINGS2_files/beacon.js"></script><script async="" src="./LCWYROCKSPRINGS2_files/ga.js" type="text/javascript"></script><script src="chrome-extension://pkljnnogdmlajgaoodihioopfdkpgjgg/Kernel.js?0.7820731684147217"></script><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script src="./LCWYROCKSPRINGS2_files/analytics.js" type="text/javascript"></script>
# <script type="text/javascript">archive_analytics.values.server_name="wwwb-app0.us.archive.org";archive_analytics.values.server_ms=460;</script>
# <link href="./LCWYROCKSPRINGS2_files/banner-styles.css" rel="stylesheet" type="text/css"/>
# <title>Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, AZ</title>
# <meta content="Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, AZ" name="title"/>
# ...

# %%
all=soup.find_all('div',{'class':'propertyRow'})

# %%
len(all)  #10 cases in each page
# Out:
# 10

# %%
all[1]
# Out:
# <div class="propertyRow" id="propertyRowC2123600598" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand C21 to view details'); document.location.href='/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598';">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyC2123600598">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="https://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598"><img class="lazyLoad" rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/tzb458q90brdmetfv72wmznb15i96" src="./LCWYROCKSPRINGS1_files/tzb458q90brdmetfv72wmznb15i96"/></a>
# </div>
# </div>
# <h4 class="propPrice">
# $452,900
# <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# ...

# %%
all[0].find_all('h4',{'class':'propPrice'})
# Out:
# [<h4 class="propPrice">
#  $725,000
#  <span class="IconPropertyFavorite16"></span>
#  </h4>]

# %%
#all[0].find_all('h4')

# %%
all[0].find('h4',{'class':'propPrice'})               #only one price available per entry so use find
# Out:
# <h4 class="propPrice">
# $725,000
# <span class="IconPropertyFavorite16"></span>
# </h4>

# %%
all[0].find('h4',{'class':'propPrice'}).text.replace('\n','').replace(" ","")                #type is string so can work on items
# Out:
# '$725,000'

# %%
for i in range(0,len(all)):
    #print(i)
    print(all[i].find('h4',{'class':'propPrice'}).text.replace('\n','').replace(" ",""))
# Out:
# $725,000
# $452,900
# $396,900
# $389,900
# $254,000
# $252,900
# $210,000
# $209,000
# $199,900
# $196,900

# %%
all[1].find_all('span',{'class':'propAddressCollapse'})[0].text       # find get the first instance
all[1].find_all('span',{'class':'propAddressCollapse'})[1].text
# Out:
# 'Rock Springs, WY 82901'

# %%
for i in range(0,len(all)):
    #print(i)
    print(all[i].find('h4',{'class':'propPrice'}).text.replace('\n','').replace(" ","")) 
    print(all[i].find_all('span',{'class':'propAddressCollapse'})[0].text)       # find get the first instance
    print(all[i].find_all('span',{'class':'propAddressCollapse'})[1].text)
    try:
        print(all[i].find('span',{'class':'infoBed'}).text)
    except:
        print('None')#pass
    
    try:
        print(all[i].find('span',{'class':'infoValueFullBath'}).text)
    except:
        print('None')#pass
  
    try:
        print(all[i].find('span',{'class':'infoValueHalfBath'}).text)
    except:
        print('None')#pass
    
    try:
        print(all[i].find('span',{'class':'infoSqFt'}).text)
    except:
        print('None')#pass
        
    try:
        for j in all[i].find_all('div',{'class':'columnGroup'}):
            for m,n in zip(j.find_all('span',{'class':'featureGroup'}),j.find_all('span',{'class':'featureName'})):
                #if(m.text=='Lot size'):
                #print(m.text,n.text)          #m feature group, n feature name iteration, zip is used for duos and move together, if one if number of items in zip not same keep up to the index for duo that dta is availabe
                if('Lot Size' in m.text):
                    print(n.text)
    except:
        print('None')#pass        
        
    print("  ")
    print("  ")
# Out:
# $725,000
# 0 Gateway
# Rock Springs, WY 82901
# None
# None
# None
# None
#
#
# $452,900
# 1003 Winchester Blvd.
# Rock Springs, WY 82901
# 4 Beds
# 4 Full Baths
# None
# None
# 0.21 Acres
#
#
# $396,900
# 600 Talladega
# Rock Springs, WY 82901
# 5 Beds
# 3 Full Baths
# None
# 3,154 Sq. Ft
#
#
# $389,900
# 3239 Spearhead Way
# Rock Springs, WY 82901
# 4 Beds
# 3 Full Baths
# 1 Half Bath
# 3,076 Sq. Ft
# Under 1/2 Acre,
#
#
# $254,000
# 522 Emerald Street
# Rock Springs, WY 82901
# 3 Beds
# 3 Full Baths
# None
# 1,172 Sq. Ft
# Under 1/2 Acre,
#
#
# $252,900
# 1302 Veteran's Drive
# Rock Springs, WY 82901
# 4 Beds
# 2 Full Baths
# None
# 1,932 Sq. Ft
# 0.27 Acres
#
#
# $210,000
# 1021 Cypress Cir
# Rock Springs, WY 82901
# 4 Beds
# 3 Full Baths
# None
# 1,676 Sq. Ft
# Under 1/2 Acre,
#
#
# $209,000
# 913 Madison Dr
# Rock Springs, WY 82901
# 3 Beds
# 2 Full Baths
# None
# 1,344 Sq. Ft
# Under 1/2 Acre,
#
#
# $199,900
# 1344 Teton Street
# Rock Springs, WY 82901
# 3 Beds
# 2 Full Baths
# ...

# %%
all[1].find_all('span',{'class':'infoBed'})  #[0].text
# Out:
# [<span class="infoBed"><b>4</b> Beds</span>]

# %%
all[1].find_all('span',{'class':'infoValueFullBath'})
# Out:
# [<span class="infoValueFullBath"><b>4</b> Full Baths</span>]

# %%
all[1].find('span',{'class':'infoBed'}).find('b').text             #only get the number
# Out:
# '4'

# %%
all[1].find('span',{'class':'infoValueFullBath'}).find('b').text    #only get the number
# Out:
# '4'

# %%
all[5].find('span',{'class':'featureName'}).text
# Out:
# '0.27 Acres'

# %%
all[5].find_all('div',{'class':'columnGroup'})   #find('span',{'class','featureGroup'})
# Out:
# [<div class="columnGroup propFeatureHeader">FEATURES:</div>,
#  <div class="columnGroup">
#  <span class="featureGroup">Lot Size: </span><span class="featureName">0.27 Acres</span>
#  </div>,
#  <div class="columnGroup">
#  <span class="featureGroup">Style: </span><span class="featureName">Bi-Level</span>
#  </div>]

# %%
for j in all[5].find_all('div',{'class':'columnGroup'}):
    #print(j)
    for m,n in zip(j.find_all('span',{'class':'featureGroup'}),j.find_all('span',{'class':'featureName'})):
        #if(m.text=='Lot size'):
        #print(m.text,n.text)          #m feature group, n feature name iteration
        if('Lot size' in m.text):
            print(n.text)

# %%
l=[ ]



for i in range(0,len(all)):
    
    d={ }
    
    d['Price']=all[i].find('h4',{'class':'propPrice'}).text.replace('\n','').replace(" ","") 
    d['Address']=all[i].find_all('span',{'class':'propAddressCollapse'})[0].text       # find get the first instance
    d['Locality']=all[i].find_all('span',{'class':'propAddressCollapse'})[1].text
    try:
        d['Beds']=all[i].find('span',{'class':'infoBed'}).find('b').text
    except:
        d['Beds']=None  #pass
    
    try:
        d['Full Baths']=all[i].find('span',{'class':'infoValueFullBath'}).find('b').text
    except:
        d['Full Baths']=None   #pass
  
    try:
        d['Half Baths']=all[i].find('span',{'class':'infoValueHalfBath'}).find('b').text
    except:
        d['Half Baths']=None     #pass
    
    try:
        d['Area']=all[i].find('span',{'class':'infoSqFt'}).find('b').text
    except:
        d['Area']=None    #pass
        
    for j in all[i].find_all('div',{'class':'columnGroup'}):
        
        for m,n in zip(j.find_all('span',{'class':'featureGroup'}),j.find_all('span',{'class':'featureName'})):
            #if(m.text=='Lot size'):
            #print(m.text,n.text)          #m feature group, n feature name iteration, zip is used for duos and move together, if one if number of items in zip not same keep up to the index for duo that dta is availabe
            if('Lot Size' in m.text):
                
                d['Lot Size']=n.text
    l.append(d)

# %%
df=pd.DataFrame(l)

# %%
df
# Out:
#                  Address   Area  Beds Full Baths Half Baths  \
# 0              0 Gateway   None  None       None       None
# 1  1003 Winchester Blvd.   None     4          4       None
# 2          600 Talladega  3,154     5          3       None
# 3     3239 Spearhead Way  3,076     4          3          1
# 4     522 Emerald Street  1,172     3          3       None
# 5   1302 Veteran's Drive  1,932     4          2       None
# 6       1021 Cypress Cir  1,676     4          3       None
# 7         913 Madison Dr  1,344     3          2       None
# 8      1344 Teton Street  1,920     3          2       None
# 9         4 Minnies Lane  1,664     3          2       None
#
#                  Locality          Lot Size     Price
# 0  Rock Springs, WY 82901               NaN  $725,000
# 1  Rock Springs, WY 82901        0.21 Acres  $452,900
# 2  Rock Springs, WY 82901               NaN  $396,900
# 3  Rock Springs, WY 82901  Under 1/2 Acre,   $389,900
# ...

# %%
#https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=20.html
import math
response = urllib.urlopen('https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/')
html4 = response.read()
soup=BeautifulSoup(html4,"html.parser")
all=soup.find_all('div',{'class':'propertyRow'})

page_num=soup.find_all('a',{'class':'Page'})[-1].text

#print(page_num)

l=[ ]


for t in range(0,int(page_num)*10,10):
    url_link='https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s='+str(t)+'.html'
    print(url_link)
    response = urllib.urlopen(url_link)
    html3 = response.read()
    soup=BeautifulSoup(html3,"html.parser")
    all=soup.find_all('div',{'class':'propertyRow'})



    for i in range(0,len(all)):

        d={ }
        try:
            
            d['Price']=all[i].find('h4',{'class':'propPrice'}).text.replace('\n','').replace(" ","") 
        except:
            d['Price']=None
        try:
            
            d['Address']=all[i].find_all('span',{'class':'propAddressCollapse'})[0].text       # find get the first instance
        except:
            d['Address']=None
        try:
            
            d['Locality']=all[i].find_all('span',{'class':'propAddressCollapse'})[1].text
        except:
            d['Locality']=None
        try:
            d['Beds']=all[i].find('span',{'class':'infoBed'}).find('b').text
        except:
            d['Beds']=None  #pass

        try:
            d['Full Baths']=all[i].find('span',{'class':'infoValueFullBath'}).find('b').text
        except:
            d['Full Baths']=None   #pass

        try:
            d['Half Baths']=all[i].find('span',{'class':'infoValueHalfBath'}).find('b').text
        except:
            d['Half Baths']=None     #pass

        try:
            d['Area']=all[i].find('span',{'class':'infoSqFt'}).find('b').text
        except:
            d['Area']=None    #pass

        for j in all[i].find_all('div',{'class':'columnGroup'}):

            for m,n in zip(j.find_all('span',{'class':'featureGroup'}),j.find_all('span',{'class':'featureName'})):
                #if(m.text=='Lot size'):
                #print(m.text,n.text)          #m feature group, n feature name iteration, zip is used for duos and move together, if one if number of items in zip not same keep up to the index for duo that dta is availabe
                if('Lot Size' in m.text):

                    d['Lot Size']=n.text
                    
        #if (math.isnan(float(d['Lot Size']))==True):
        #    d['Lot Size']=None
            
        l.append(d)
# Out:
# https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=0.html
# https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=10.html
# https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=20.html

# %%
df=pd.DataFrame(l)
df
# Out:
#                           Address   Area  Beds Full Baths Half Baths  \
# 0                       0 Gateway   None  None       None       None
# 1           1003 Winchester Blvd.   None     4          4       None
# 2                   600 Talladega  3,154     5          3       None
# 3              3239 Spearhead Way  3,076     4          3          1
# 4              522 Emerald Street  1,172     3          3       None
# 5            1302 Veteran's Drive  1,932     4          2       None
# 6                1021 Cypress Cir  1,676     4          3       None
# 7                  913 Madison Dr  1,344     3          2       None
# 8               1344 Teton Street  1,920     3          2       None
# 9                  4 Minnies Lane  1,664     3          2       None
# 10                  9339 Sd 26900  2,560  None       None       None
# 11               RR674P13 Hwy 377  2,000  None       None       None
# 12                       0 Hwy 41   None  None       None       None
# ...

# %%
hostname = 'localhost'
username = 'postgres'
password = 'test'
database = 'postgres'
import psycopg2
from sqlalchemy import create_engine


myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
engine = create_engine('postgresql://postgres:test@localhost:5432/postgres')    # 'postgresql://username:password@localhost:5432/mydatabase'
#engine = create_engine('postgresql+psycopg2://postgres:test@localhost:5432/postgres')
df.to_sql('realestate2',engine)
myConnection.commit()
myConnection.close()
